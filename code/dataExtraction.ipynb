# %%
import pandas as pd
import numpy as np

# %%
sem1Parent = pd.read_excel('/Users/sahilbavishi/Desktop/Edi/hackTheBurgh/HackTheBurgh25/data/41 TT Parent Data - Sem1 23-24.xlsx', sheet_name='Sem1 Data')
sem1Child = pd.read_excel('/Users/sahilbavishi/Desktop/Edi/hackTheBurgh/HackTheBurgh25/data/42 TT Child Data - Sem1 23-24.xlsx', sheet_name='Sem1 TT')

sem2Parent = pd.read_excel('/Users/sahilbavishi/Desktop/Edi/hackTheBurgh/HackTheBurgh25/data/43 TT Parent Data - Sem2 23-24.xlsx', sheet_name='Sem2 Data')
sem2Child = pd.read_excel('/Users/sahilbavishi/Desktop/Edi/hackTheBurgh/HackTheBurgh25/data/44 TT Child Data - Sem2 23-24.xlsx', sheet_name='Sem2 TT')

# %%
### PLEASE READ
'''
We can use the parent data, and use it for unique courses. Which will be embedded. 
We can map these embeddings to the MODULE ID.

Then we find predictions.

Use these predictions and find the mapped MODULE ID.

Use module ID in child data to ensure all constraints are met. There is timing, weeks and location of different lectures and tutorials there.

Done. So Easy :)

'''
# Out:
# '\nWe can use the parent data, and use it for unique courses. Which will be embedded. \nWe can map these embeddings to the MODULE ID.\n\nThen we find predictions.\n\nUse these predictions and find the mapped MODULE ID.\n\nUse module ID in child data to ensure all constraints are met. There is timing, weeks and location of different lectures and tutorials there.\n\nDone. So Easy :)\n\n'

# %%
sem1Parent.head()
# Out:
#                Name of Department Host Key of Module of Activity Or Parents  \
# 0  Deanery of Biomedical Sciences                        MSBM08002_SS1_SEM1
# 1  Deanery of Biomedical Sciences                        MSBM08002_SS1_SEM1
# 2  Deanery of Biomedical Sciences                          MSBM10011_SS1_YR
# 3  Deanery of Biomedical Sciences                          MSBM10011_SS1_YR
# 4  Deanery of Biomedical Sciences                          MSBM10011_SS1_YR
#
#   Name of Module of Activity Or Parents Name of Type       Activity ID
# 0                   Medical Sciences 1.    *Workshop      #SPLUS03A0D8
# 1                   Medical Sciences 1.    *Workshop      #SPLUS03A0DA
# 2                    Medical Sciences 4    *Tutorial  #SPLUS03A0E8 002
# 3                    Medical Sciences 4    *Tutorial  #SPLUS03A0E8 001
# 4                    Medical Sciences 4    *Tutorial  #SPLUS03A0EA 002

# %%
sem1Child.head(5)
# Out:
#                Name of Department           Module ID       Name of Module  \
# 0  Deanery of Biomedical Sciences  MSBM08002_SS1_SEM1  Medical Sciences 1.
# 1  Deanery of Biomedical Sciences  MSBM08002_SS1_SEM1  Medical Sciences 1.
# 2  Deanery of Biomedical Sciences    MSBM10011_SS1_YR   Medical Sciences 4
# 3  Deanery of Biomedical Sciences    MSBM10011_SS1_YR   Medical Sciences 4
# 4  Deanery of Biomedical Sciences    MSBM10011_SS1_YR   Medical Sciences 4
#
#   Name of Type       Activity ID                              Name  Day  \
# 0    *Workshop      #SPLUS03A0D8   Medical Sciences 1 - Workshop/A  Tue
# 1    *Workshop      #SPLUS03A0DA   Medical Sciences 1 - Workshop/B  Tue
# 2    *Tutorial  #SPLUS03A0E8 002  Medical Sciences 4 - Tutorial/01  Wed
# 3    *Tutorial  #SPLUS03A0E8 001  Medical Sciences 4 - Tutorial/01  Wed
# 4    *Tutorial  #SPLUS03A0EA 002  Medical Sciences 4 - Tutorial/02  Wed
#
#   Start Time  End Time Whole-Class/Subgroup  Size  Real Size  Duration  \
# ...
