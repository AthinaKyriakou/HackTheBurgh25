# %%
# Settings
DRIVEmount = True
GHpush = False

from google.colab import drive
import os
from pathlib import Path
from datetime import datetime

# %%
# Mounting/updating Drive
if DRIVEmount:
  # %cd /content
  if os.path.ismount('/content/drive'):
    drive.flush_and_unmount()
  drive.mount('/content/drive')

  # Selecting correct path (eventually insert the correct one for ur shared drive)
  paths = ["/content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh",
          "/content/drive/MyDrive/HackTheBurgh"]
  for path in paths:
    if Path(path).exists():
      # %cd "{path}"
  # %ls
# Out:
# /content
# Mounted at /content/drive
# /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh
#  base_HTB.ipynb             data/             Study_plans_builder.ipynb
#  Courses_extraction.ipynb  'Drive&GH.ipynb'   Untitled0.ipynb

# %%
import json

# Load JSON data from file
with open("data/informatics_course_info.json", "r", encoding="utf-8") as file:
    json_data = json.load(file)

# Generate dictionary mapping course_code to semester
yearSemester = {course["course_code"]: course["semester"] for course in json_data}

# Print or use the dictionary
print(yearSemester)
# Out:
# {'INFR08031': 'Semester 1', 'INFR08020': 'Semester 2', 'INFR08025': 'Semester 1', 'INFR08029': 'Semester 2', 'INFR08030': 'Full Year', 'INFR08026': 'Full Year', 'INFR08032': 'Semester 2', 'INFR08027': 'Semester 1', 'INFR08010': 'Semester 2', 'INFR08033': 'Full Year', 'INFR09053': 'Semester 2', 'INFR09051': 'Semester 1', 'INFR09032': 'Semester 2', 'INFR10052': 'Semester 1', 'INFR10087': 'Semester 1', 'INFR10065': 'Semester 2', 'INFR10054': 'Semester 1', 'INFR10076': 'Semester 1', 'INFR10074': 'Semester 2', 'INFR10067': 'Semester 1', 'INFR10077': 'Full Year', 'INFR10061': 'Semester 1', 'INFR10078': 'Semester 2', 'INFR10081': '', 'INFR10044': 'Full Year', 'INFR10084': 'Full Year', 'INFR10082': '', 'INFR10080': 'Semester 1', 'INFR10085': 'Semester 1', 'INFR10059': 'Semester 1', 'INFR10051': 'Full Year', 'INFR10086': 'Semester 2', 'INFR10089': 'Semester 1', 'INFR10088': 'Semester 1', 'INFR10079': 'Semester 2', 'INFR10022': 'Semester 1', 'INFR10064': 'Semester 2', 'INFR10057': 'Semester 1', 'INFR10083': '', 'INFR11125': 'Semester 1', 'INFR11199': 'Semester 2', 'INFR11217': 'Semester 2', 'INFR11213': 'Semester 1', 'INFR11156': 'Semester 2', 'INFR11279': 'Semester 2', 'INFR11020': 'Semester 2', 'INFR11218': 'Semester 2', 'INFR11245': 'Semester 2', 'INFR11249': 'Semester 2', 'INFR11258': 'Semester 1', 'INFR11211': 'Semester 1', 'INFR11180': '', 'INFR11033': 'Semester 2', 'INFR11219': 'Semester 2', 'INFR11160': '', 'INFR11005': '', 'INFR11144': 'Semester 1', 'INFR11238': '', 'INFR11206': 'Semester 2', 'INFR11231': 'Semester 2', 'INFR11094': 'Semester 1', 'INFR11095': '', 'INFR11281': '', 'INFR11128': '', 'INFR11036': 'Semester 2', 'INFR11233': 'Semester 2', 'INFR11102': '', 'INFR11209': 'Semester 1', 'INFR11021': '', 'INFR11220': '', 'INFR11241': 'Semester 2', 'INFR11247': 'Semester 2', 'INFR11246': 'Semester 1', 'INFR11244': 'Semester 1', 'INFR11212': 'Semester 2', 'INFR11278': 'Semester 2', 'INFR11115': 'Semester 1', 'INFR11116': 'Flexible', 'INFR11117': 'Flexible', 'INFR11007': '', 'INFR11190': '', 'INFR11198': 'Semester 1', 'INFR11022': 'Semester 1', 'INFR11194': '', 'INFR11088': '', 'INFR11283': '', 'INFR11129': '', 'INFR11262': 'Full Year', 'INFR11200': '', 'INFR11250': '', 'INFR11193': '', 'INFR11203': '', 'INFR11017': 'Semester 1', 'INFR11140': '', 'INFR11251': '', 'INFR11257': 'Semester 2', 'INFR11192': '', 'INFR11204': '', 'INFR11197': '', 'INFR11147': 'Semester 2', 'INFR11136': 'Semester 1', 'INFR11274': '', 'INFR11146': '', 'INFR11131': 'Semester 2', 'INFR11221': 'Semester 2', 'INFR11189': '', 'INFR11099': '', 'INFR11256': 'Semester 1', 'INFR11222': '', 'INFR11242': 'Semester 2', 'INFR11243': 'Semester 2', 'INFR11205': 'Semester 2', 'INFR11195': '', 'INFR11215': '', 'INFR11093': 'Full Year', 'INFR11275': '', 'INFR11077': 'Block 5 (Sem 2) and beyond', 'INFR11132': 'Full Year', 'INFR11223': 'Full Year', 'INFR11269': 'Semester 2', 'INFR11280': 'Semester 2', 'INFR11271': 'Full Year', 'INFR11270': 'Full Year', 'INFR11272': 'Full Year', 'INFR11202': 'Semester 2', 'INFR11224': 'Semester 2', 'INFR11130': 'Semester 1', 'INFR11097': 'Flexible', 'INFR11207': 'Semester 2', 'INFR11234': 'Semester 2', 'INFR11248': 'Semester 1', 'INFR11161': '', 'INFR11157': 'Semester 2', 'INFR11225': 'Semester 2', 'INFR11024': '', 'INFR11023': 'Semester 2', 'INFR11226': 'Semester 2', 'INFR11264': 'Block 5 (Sem 2) and beyond', 'INFR11150': 'Semester 1', 'INFR11239': '', 'INFR11240': 'Semester 2', 'INFR11252': 'Semester 2', 'INFR11134': '', 'INFR11235': '', 'INFR11260': 'Semester 1', 'INFR11255': 'Semester 1', 'INFR11187': 'Semester 2', 'INFR11227': 'Semester 2', 'INFR11268': 'Full Year', 'INFR11273': '', 'INFR11267': 'Full Year', 'INFR11201': '', 'INFR11010': 'Semester 2', 'INFR11236': 'Semester 2', 'INFR11216': 'Semester 2', 'INFR11259': 'Full Year', 'INFR11098': 'Semester 1', 'INFR11208': '', 'INFR11228': '', 'INFR11210': 'Full Year', 'INFR11237': 'Full Year', 'INFR11254': 'Semester 1', 'INFR11124': '', 'INFR11214': '', 'INFR11253': '', 'INFR11145': 'Ful ...

# %%
import json
import pandas as pd
import pickle

# Load JSON data from file
with open("data/informatics_course_info.json", "r", encoding="utf-8") as file:
    json_data = json.load(file)

# Load Excel data
df = pd.read_excel("data/01 Programme Course options data.xlsx", sheet_name="Programme Course Options data", usecols=["Course Code", "Programme Year"])
df.dropna(inplace=True)
df["Programme Year"] = df["Programme Year"].astype(int)
# Convert the DataFrame into a dictionary for quick lookup
year_dict = dict(zip(df["Course Code"], df["Programme Year"]))

# Generate the final dictionary mapping course_code to (year, semester)
yearSemester = {
    course["course_code"]: (year_dict.get(course["course_code"], 0), course["semester"])
    for course in json_data
}

# Print or use the dictionary
print(yearSemester)

with open('data/yearSemester.pkl', 'wb') as f:
    pickle.dump(yearSemester, f)
# Out:
# {'INFR08031': (2, 'Semester 1'), 'INFR08020': (1, 'Semester 2'), 'INFR08025': (1, 'Semester 1'), 'INFR08029': (1, 'Semester 2'), 'INFR08030': (2, 'Full Year'), 'INFR08026': (2, 'Full Year'), 'INFR08032': (2, 'Semester 2'), 'INFR08027': (2, 'Semester 1'), 'INFR08010': (2, 'Semester 2'), 'INFR08033': (0, 'Full Year'), 'INFR09053': (3, 'Semester 2'), 'INFR09051': (3, 'Semester 1'), 'INFR09032': (3, 'Semester 2'), 'INFR10052': (3, 'Semester 1'), 'INFR10087': (4, 'Semester 1'), 'INFR10065': (4, 'Semester 2'), 'INFR10054': (4, 'Semester 1'), 'INFR10076': (4, 'Semester 1'), 'INFR10074': (4, 'Semester 2'), 'INFR10067': (4, 'Semester 1'), 'INFR10077': (4, 'Full Year'), 'INFR10061': (4, 'Semester 1'), 'INFR10078': (3, 'Semester 2'), 'INFR10081': (4, ''), 'INFR10044': (4, 'Full Year'), 'INFR10084': (4, 'Full Year'), 'INFR10082': (4, ''), 'INFR10080': (4, 'Semester 1'), 'INFR10085': (4, 'Semester 1'), 'INFR10059': (3, 'Semester 1'), 'INFR10051': (4, 'Full Year'), 'INFR10086': (3, 'Semester 2'), 'INFR10089': (3, 'Semester 1'), 'INFR10088': (4, 'Semester 1'), 'INFR10079': (4, 'Semester 2'), 'INFR10022': (3, 'Semester 1'), 'INFR10064': (4, 'Semester 2'), 'INFR10057': (4, 'Semester 1'), 'INFR10083': (4, ''), 'INFR11125': (5, 'Semester 1'), 'INFR11199': (1, 'Semester 2'), 'INFR11217': (4, 'Semester 2'), 'INFR11213': (4, 'Semester 1'), 'INFR11156': (0, 'Semester 2'), 'INFR11279': (0, 'Semester 2'), 'INFR11020': (1, 'Semester 2'), 'INFR11218': (4, 'Semester 2'), 'INFR11245': (1, 'Semester 2'), 'INFR11249': (4, 'Semester 2'), 'INFR11258': (0, 'Semester 1'), 'INFR11211': (1, 'Semester 1'), 'INFR11180': (0, ''), 'INFR11033': (1, 'Semester 2'), 'INFR11219': (4, 'Semester 2'), 'INFR11160': (1, ''), 'INFR11005': (0, ''), 'INFR11144': (1, 'Semester 1'), 'INFR11238': (4, ''), 'INFR11206': (1, 'Semester 2'), 'INFR11231': (0, 'Semester 2'), 'INFR11094': (5, 'Semester 1'), 'INFR11095': (0, ''), 'INFR11281': (0, ''), 'INFR11128': (1, ''), 'INFR11036': (1, 'Semester 2'), 'INFR11233': (5, 'Semester 2'), 'INFR11102': (4, ''), 'INFR11209': (4, 'Semester 1'), 'INFR11021': (0, ''), 'INFR11220': (0, ''), 'INFR11241': (1, 'Semester 2'), 'INFR11247': (4, 'Semester 2'), 'INFR11246': (4, 'Semester 1'), 'INFR11244': (1, 'Semester 1'), 'INFR11212': (0, 'Semester 2'), 'INFR11278': (0, 'Semester 2'), 'INFR11115': (0, 'Semester 1'), 'INFR11116': (0, 'Flexible'), 'INFR11117': (0, 'Flexible'), 'INFR11007': (0, ''), 'INFR11190': (0, ''), 'INFR11198': (2, 'Semester 1'), 'INFR11022': (0, 'Semester 1'), 'INFR11194': (0, ''), 'INFR11088': (4, ''), 'INFR11283': (0, ''), 'INFR11129': (4, ''), 'INFR11262': (0, 'Full Year'), 'INFR11200': (1, ''), 'INFR11250': (0, ''), 'INFR11193': (0, ''), 'INFR11203': (0, ''), 'INFR11017': (4, 'Semester 1'), 'INFR11140': (1, ''), 'INFR11251': (5, ''), 'INFR11257': (0, 'Semester 2'), 'INFR11192': (0, ''), 'INFR11204': (0, ''), 'INFR11197': (0, ''), 'INFR11147': (1, 'Semester 2'), 'INFR11136': (1, 'Semester 1'), 'INFR11274': (0, ''), 'INFR11146': (5, ''), 'INFR11131': (1, 'Semester 2'), 'INFR11221': (4, 'Semester 2'), 'INFR11189': (0, ''), 'INFR11099': (1, ''), 'INFR11256': (0, 'Semester 1'), 'INFR11222': (4, ''), 'INFR11242': (5, 'Semester 2'), 'INFR11243': (5, 'Semester 2'), 'INFR11205': (1, 'Semester 2'), 'INFR11195': (0, ''), 'INFR11215': (4, ''), 'INFR11093': (5, 'Full Year'), 'INFR11275': (0, ''), 'INFR11077': (3, 'Block 5 (Sem 2) and beyond'), 'INFR11132': (1, 'Full Year'), 'INFR11223': (4, 'Full Year'), 'INFR11269': (0, 'Semester 2'), 'INFR11280': (0, 'Semester 2'), 'INFR11271': (0, 'Full Year'), 'INFR11270': (0, 'Full Year'), 'INFR11272': (0, 'Full Year'), 'INFR11202': (1, 'Semester 2'), 'INFR11224': (4, 'Semester 2'), 'INFR11130': (1, 'Semester 1'), 'INFR11097': (1, 'Flexible'), 'INFR11207': (1, 'Semester 2'), 'INFR11234': (5, 'Semester 2'), 'INFR11248': (5, 'Semester 1'), 'INFR11161': (1, ''), 'INFR11157': (1, 'Semester 2'), 'INFR11225': (4, 'Semester 2'), 'INFR11024': (5, ''), 'INFR11023': (2, 'Semester 2'), 'INFR11226': (4, 'Semester 2'), ...
