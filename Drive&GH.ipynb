# %% [markdown]
# ## Google Drive and GitHub initialization

# %%
# Settings
DRIVEmount = True
GHpush = True

from google.colab import drive
import os
from pathlib import Path
from datetime import datetime

# %%
# Mounting/updating Drive
if DRIVEmount:
  # %cd /content
  if os.path.ismount('/content/drive'):
    drive.flush_and_unmount()
  drive.mount('/content/drive')

  # Selecting correct path (eventually insert the correct one for ur shared drive)
  paths = ["/content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh",
          "/content/drive/MyDrive/HackTheBurgh"]
  for path in paths:
    if Path(path).exists():
      # %cd "{path}"
  # %ls
# Out:
# /content
# Mounted at /content/drive
# /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh
# 'Drive&GH.ipynb'

# %%
# GitHub interaction initialization
if GHpush:
  # !git config --global user.name "AthinaKyriakou"
  # !git config --global user.email "34518449+AthinaKyriakou@users.noreply.github.com"
  # !git init
  # !git remote add origin https://github.com/AthinaKyriakou/HackTheBurgh25.git
  # !git add .
  timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  # !git commit -m "Commit at {timestamp}"
  # !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh/.git/
# error: remote origin already exists.
# [master c88794a] Commit at 2025-03-01 16:20:54
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Drive&GH.ipynb (100%)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
token = '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'
repo_url = f'https://{token}:x-oauth-basic@github.com/AthinaKyriakou/HackTheBurgh25.git'

# GitHub interaction initialization
if GHpush:
    # !git config --global user.name "AthinaKyriakou"
    # !git config --global user.email "34518449+AthinaKyriakou@users.noreply.github.com"
    # !git init
    # !git remote set-url origin {repo_url}  # Set the token-authenticated URL
    # !git add .

    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    # !git commit -m f"Commit at {timestamp}"

    # Push to GitHub
    # !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh/.git/
# [master f857b0a] fCommit at 2025-03-01 16:21:40
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (9/9), 4.46 KiB | 157.00 KiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), done.
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/AthinaKyriakou/HackTheBurgh25/pull/new/master
# remote:
# To https://github.com/AthinaKyriakou/HackTheBurgh25.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
