# %% [markdown]
# ## Google Drive and GitHub initialization

# %%
# Settings
DRIVEmount = True
GHpush = True

from google.colab import drive
import os
from pathlib import Path
from datetime import datetime

# %%
# Mounting/updating Drive
if DRIVEmount:
  # %cd /content
  if os.path.ismount('/content/drive'):
    drive.flush_and_unmount()
  drive.mount('/content/drive')

  # Selecting correct path (eventually insert the correct one for ur shared drive)
  paths = ["/content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh",
          "/content/drive/MyDrive/HackTheBurgh"]
  for path in paths:
    if Path(path).exists():
      # %cd "{path}"
  # %ls
# Out:
# /content
# Mounted at /content/drive
# /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh
#  base_HTB.ipynb   code/   course_info.json   data/  'Drive&GH.ipynb'

# %%
# GitHub interaction initialization
if GHpush:
  token = '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'
  repo_url = f'https://{token}:x-oauth-basic@github.com/AthinaKyriakou/HackTheBurgh25.git'
  # !git config --global user.name "AthinaKyriakou"
  # !git config --global user.email "34518449+AthinaKyriakou@users.noreply.github.com"
  # !git init
  # !git remote set-url origin {repo_url}
  # !git add .
  timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  # !git commit -m f"Commit at {timestamp}"
  # !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/drive/Othercomputers/Il mio laptop/Matteo/Magistrale/Un. of Edinburgh/Attività/HackTheBurgh/.git/
# [master f53fa7c] fCommit at 2025-03-01 18:17:38
#  14 files changed, 2277 insertions(+), 2 deletions(-)
#  rewrite Drive&GH.ipynb (89%)
#  rewrite base_HTB.ipynb (91%)
#  rename course_description.txt => code/course_description.txt (100%)
#  create mode 100644 code/dataExtraction.ipynb
#  create mode 100644 data/22 Example course mark data 1.xlsx
#  create mode 100644 data/23 Example course mark data 2.xlsx
#  create mode 100644 data/24 Example course mark data 3.xlsx
#  create mode 100644 data/41 TT Parent Data - Sem1 23-24.xlsx
#  create mode 100644 data/42 TT Child Data - Sem1 23-24.xlsx
#  create mode 100644 data/43 TT Parent Data - Sem2 23-24.xlsx
#  create mode 100644 data/44 TT Child Data - Sem2 23-24.xlsx
#  create mode 100644 data/Enclosure FOI2024 00779.pdf
#  create mode 100644 data/course_description.txt
#  create mode 100644 data/course_info.json
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 19.10 MiB | 7.82 MiB/s, done.
# Total 16 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/AthinaKyriakou/HackTheBurgh25.git
#    a917202..f53fa7c  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
